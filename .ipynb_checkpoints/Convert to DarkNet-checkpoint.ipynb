# %%
import pandas as pd
import matplotlib.pyplot as plt
from pydicom import dcmread
from pydicom.data import get_testdata_file
import cv2

# %%
ds = dcmread("stage_2_train_images/000db696-cf54-4385-b10b-6b16fbb3f985.dcm")
cv2.imwrite("test.jpg",ds.pixel_array)

# %%
dataset = pd.read_csv("stage_2_train_labels.csv")

# %%
array = dataset[dataset['Target']!=0].values

# %%
for x in array:
    name = x[0]
    ds = dcmread("stage_2_train_images/"+ name +".dcm")
    cv2.imwrite("obj/"+name+".jpg",ds.pixel_array)
    file = open("obj/"+name+".txt",'w')
    file.write("0 "+str(x[1])+" "+str(x[2])+" "+str(x[3])+" "+str(x[4]))
    file.close()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-19-3cd5481ede90> in <module>
#       2     name = x[0]
#       3     ds = dcmread("stage_2_train_images/"+ name +".dcm")
# ----> 4     cv2.imwrite("obj/"+name+".jpg",ds.pixel_array)
#       5     file = open("obj/"+name+".txt",'w')
#       6     file.write("0 "+str(x[1])+" "+str(x[2])+" "+str(x[3])+" "+str(x[4]))
#
# KeyboardInterrupt:
